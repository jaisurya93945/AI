# %% [markdown]
# <a href="https://colab.research.google.com/github/jaisurya93945/AI/blob/main/month1/week1_python_foundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 – Python Foundations
#
# ## Goal:
# - Master OOP
# - Exception Handling
# - Logging
# - CSV Handling
#
# ## Author:
# JAISURYA B

# %%
print("github sync test")
# Out:
# github sync test

# %% [markdown]
# # WEEK - 1
# ## imports

# %%
import pandas as pd
import logging
import sys

#logging handlers
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    stream=sys.stdout
)

logging.info("Logging initialized successfully.")
# Out:
# 2026-03-03 15:15:41,935 [INFO] Logging initialized successfully.

# %% [markdown]
# ## DatasetLoader Class

# %%
class DatasetLoader:
  def __init__(self, filepath):
    self.filepath = filepath
    logging.info(f"Initializing DatasetLoader with filepath: {filepath}")

  def load_data(self):
    try:
      data = pd.read_csv(self.filepath)
      logging.info("File loaded successfully.")
      return data
    except FileNotFoundError:
      logging.error("File not found.")
      return None

  def get_shape(self, data):
    if data is not None:
      logging.info(f"Dataset shape: {data.shape}")
      return data.shape
    else:
      logging.warning("Data is None.")
      return None

# %%
loader = DatasetLoader("/content/retail_customer_segmentation.csv")
data = loader.load_data()
loader.get_shape(data)
# Out:
# 2026-03-03 15:15:41,956 [INFO] Initializing DatasetLoader with filepath: /content/retail_customer_segmentation.csv
# 2026-03-03 15:15:42,021 [INFO] File loaded successfully.
# 2026-03-03 15:15:42,022 [INFO] Dataset shape: (50000, 14)
# (50000, 14)

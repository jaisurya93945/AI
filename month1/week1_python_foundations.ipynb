# %% [markdown]
# <a href="https://colab.research.google.com/github/jaisurya93945/AI/blob/main/month1/week1_python_foundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 – Python Foundations
#
# ## Goal:
# - Master OOP
# - Exception Handling
# - Logging
# - CSV Handling
#
# ## Author:
# JAISURYA B

# %%
print("github sync test")
# Out:
# github sync test

# %% [markdown]
# # WEEK - 1
# ## imports

# %%
import pandas as pd
import logging
import sys

#logging handlers
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    stream=sys.stdout
)

logging.info("Logging initialized successfully.")
# Out:
# 2026-03-03 14:58:08,129 [INFO] Logging initialized successfully.
